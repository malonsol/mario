# %% [markdown]
# A few years ago, a discrimination lawsuit was filed against the California DDS claiming that White Non-Hispanics were receiving more funding than Hispanics. If this was true, the DDS faced some serious implications. In order to investigate the issue, several statisticians were hired to further analyze the data.
#
# After viewing the summary, this sample of 1000 individuals seems like a good representation of the state of California as a whole. The ages look to be semi-uniformly distributed, and the ethnicity frequencies seem to accurately represent the demographic proportions in the state.
#
# Now, we are interested in determining if there is any ethnic bias regarding the expenditures.

# %%
import pandas as pd
url='https://raw.githubusercontent.com/KaonToPion/datasets/main/californiaDDSDataV2.csv'
df=pd.read_csv(url)

# %%
df.head()
# Out:
#       Id Age Cohort  Age  Gender  Expenditures           Ethnicity
# 0  10210   13 to 17   17  Female          2113  White not Hispanic
# 1  10409   22 to 50   37    Male         41924  White not Hispanic
# 2  10486     0 to 5    3    Male          1454            Hispanic
# 3  10538   18 to 21   19  Female          6400            Hispanic
# 4  10568   13 to 17   13    Male          4412  White not Hispanic

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,ax=plt.subplots(figsize=(10,6))
sns.boxplot(data=df,x='Expenditures',y='Ethnicity',ax=ax)
ax.set_title('expenditures vs ethnicity')
# Out:
# Text(0.5, 1.0, 'expenditures vs ethnicity')

# %%
fig,ax1=plt.subplots(figsize=(10,6))
df_aux=df[(df['Ethnicity']=='Hispanic')|(df['Ethnicity']=='White not Hispanic')].copy()
sns.barplot(data=df_aux,x='Age Cohort',y='Expenditures',hue='Ethnicity' ,estimator=np.max)

# %%
df['Age Cohort'].unique()
# Out:
# array(['13 to 17', '22 to 50', '0 to 5', '18 to 21', '51+', '6 to 12'],
#       dtype=object)

# %%
fig,ax1=plt.subplots(figsize=(10,6))

order_list=['0 to 5','6 to 12','13 to 17',   '18 to 21','22 to 50', '51+' ]
sns.boxplot(data=df,x='Expenditures',y='Age Cohort',ax=ax1 ,order=order_list)

# %%
for age_group in order_list:
  fig,ax1=plt.subplots(figsize=(10,6))
  #df_aux=df[(df['Ethnicity']=='Hispanic')|(df['Ethnicity']=='White not Hispanic')].copy()
  df_aux=df[df['Age Cohort']==age_group].copy()
  sns.violinplot(data=df_aux,x='Expenditures',y='Ethnicity',ax=ax1)
  ax1.set_title(age_group)
  ax1.set_xlim(0,80000)

# %%
sns.countplot(data=df,x='Age Cohort')

# %%
fig,ax=plt.subplots(figsize=(10,5))

sns.histplot(data=df[df['Ethnicity']=='White not Hispanic'],x='Age',ax=ax, stat='probability')

sns.histplot(data=df[df['Ethnicity']=='Hispanic'],x='Age',ax=ax,color='orange',stat='probability')
