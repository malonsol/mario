# %% [markdown]
# A few years ago, a discrimination lawsuit was filed against the California DDS claiming that White Non-Hispanics were receiving more funding than Hispanics. If this was true, the DDS faced some serious implications. In order to investigate the issue, several statisticians were hired to further analyze the data.
#
# After viewing the summary, this sample of 1000 individuals seems like a good representation of the state of California as a whole. The ages look to be semi-uniformly distributed, and the ethnicity frequencies seem to accurately represent the demographic proportions in the state.
#
# Now, we are interested in determining if there is any ethnic bias regarding the expenditures.

# %%
import pandas as pd
url='https://raw.githubusercontent.com/KaonToPion/datasets/main/californiaDDSDataV2.csv'
df=pd.read_csv(url)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#       Id Age Cohort  Age  Gender  Expenditures           Ethnicity
# 0  10210   13 to 17   17  Female          2113  White not Hispanic
# 1  10409   22 to 50   37    Male         41924  White not Hispanic
# 2  10486     0 to 5    3    Male          1454            Hispanic
# 3  10538   18 to 21   19  Female          6400            Hispanic
# 4  10568   13 to 17   13    Male          4412  White not Hispanic

# %%
group = df.groupby('Ethnicity').mean()
group
# Out:
#                               Id        Age  Expenditures
# Ethnicity
# American Indian     61524.500000  53.250000  36438.250000
# Asian               57662.937984  23.069767  18392.372093
# Black               53498.915254  24.644068  20884.593220
# Hispanic            53741.686170  17.375000  11065.569149
# Multi Race          59606.153846  10.269231   4456.730769
# Native Hawaiian     71181.333333  35.666667  42782.333333
# Other               62868.500000  16.000000   3316.500000
# White not Hispanic  54179.246883  27.975062  24697.548628

# %%
plt.bar(group.index, group['Expenditures']);
plt.xticks(rotation='45');

# %%
fig,ax = plt.subplots(figsize=(5,3));
ax.bar(group.index,group['Expenditures'],label='Expenditures')

ax.set_xticks(group.index)

ax.legend(loc='best');

# %%
fig,ax = plt.subplots(figsize=(8,5))
sns.boxplot(data=df,x='Expenditures',y='Ethnicity');

# %%
fig,ax = plt.subplots(figsize=(8,5))
sns.violinplot(data=df,x='Expenditures',y='Ethnicity');

# %% [markdown]
# Por edad:

# %%
df['Age Cohort'] = pd.cut(df['Age'], bins=5)

# %%
fig,ax = plt.subplots(figsize=(8,5))
sns.boxplot(data=df,x='Expenditures',y='Age Cohort');

# %%
fig,ax1 = plt.subplots(figsize=(8,5))
df_aux = (df[df['Ethnicity'] == 'Hispanic']|df[df['Ethnicity'] == 'White not Hispanic']).copy()
sns.barplot(date=df_aux,x='Age Cohort',y='Expenditures',hue='Ethnicity');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# TypeError: unsupported operand type(s) for |: 'float' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-4587b6d92f36> in <module>
#       1 fig,ax1 = plt.subplots(figsize=(8,5))
# ----> 2 df_aux = (df[df['Ethnicity'] == 'Hispanic']|df[df['Ethnicity'] == 'White not Hispanic']).copy()
#       3 sns.barplot(date=df_aux,x='Age Cohort',y='Expenditures',hue='Ethnicity');
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     765
#     766             left, right = self.align(other, join="outer", level=level, copy=False)
# --> 767             new_data = left._combine_frame(right, pass_op, fill_value)
#     768             return left._construct_result(new_data)
#     769
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _combine_frame(self, other, func, fill_value, level)
#    5298         if ops.should_series_dispatch(self, other, func):
#    5299             # iterate over columns
# -> 5300             new_data = ops.dispatch_to_series(self, other, _arith_op)
#    5301         else:
#    5302             with np.errstate(all="ignore"):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     417         raise NotImplementedError(right)
#     418
# --> 419     new_data = expressions.evaluate(column_op, str_rep, left, right)
#     420     return new_data
#     421
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     206     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#     210
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#     123     return result
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in column_op(a, b)
#     386
#     387         def column_op(a, b):
# --> 388             return {i: func(a.iloc[:, i], b.iloc[:, i]) for i in range(len(a.columns))}
#     389
#     390     elif isinstance(right, ABCSeries) and axis == "columns":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in <dictcomp>(.0)
#     386
#     387         def column_op(a, b):
# --> 388             return {i: func(a.iloc[:, i], b.iloc[:, i]) for i in range(len(a.columns))}
#     389
#     390     elif isinstance(right, ABCSeries) and axis == "columns":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     550         rvalues = extract_array(other, extract_numpy=True)
#     551
# --> 552         res_values = logical_op(lvalues, rvalues, op)
#     553         return _construct_result(self, res_values, index=self.index, name=res_name)
#     554
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in logical_op(left, right, op)
#     364         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
#     365
# --> 366         res_values = na_logical_op(lvalues, rvalues, op)
#     367         res_values = filler(res_values)  # type: ignore
#     368
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     279             x = ensure_object(x)
#     280             y = ensure_object(y)
# --> 281             result = libops.vec_binop(x, y, op)
#     282         else:
#     283             # let null fall thru
#
# pandas/_libs/ops.pyx in pandas._libs.ops.vec_binop()
#
# pandas/_libs/ops.pyx in pandas._libs.ops.vec_binop()
#
# TypeError: unsupported operand type(s) for |: 'float' and 'bool'

# %%
fig,ax = plt.subplots(figsize=(8,5))
sns.histplot(data=df[df['Ethnicity'] == 'White not Hispanic'],x='Age',ax=ax)
sns.histplot(data=df[df['Ethnicity'] == 'Hispanic'],x='Age',ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-71a2729ec27c> in <module>
#       1 fig,ax = plt.subplots(figsize=(8,5))
# ----> 2 sns.histplot(data=df[df['Ethnicity'] == 'White not Hispanic'],x='Age',ax=ax)
#       3 sns.histplot(data=df[df['Ethnicity'] == 'Hispanic'],x='Age',ax=ax)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
# !pip install seaborn --upgrade
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      |████████████████████████████████| 283 kB 4.4 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in /home/dsc/anaconda3/lib/python3.8/site-packages (from seaborn) (1.0.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.0 in /home/dsc/anaconda3/lib/python3.8/site-packages (from seaborn) (1.5.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from seaborn) (3.2.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /home/dsc/anaconda3/lib/python3.8/site-packages (from seaborn) (1.18.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/dsc/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2020.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/dsc/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /home/dsc/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/dsc/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas>=0.23->seaborn) (1.15.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.9.0
#     Uninstalling seaborn-0.9.0:
#       Successfully uninstalled seaborn-0.9.0
# Successfully installed seaborn-0.11.0
